# %%
import os
os.chdir('../../')

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets as datasets
from models import cmlp
from utilities import fits
from flax import linen as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import brier_score_loss
from utilities.plot import plot_binary_class,plot_caliberation_classification
import tensorflow_probability.substrates.jax as tfp
tfd = tfp.distributions
from functools import partial
from jax.flatten_util import ravel_pytree
import blackjax
from probml_utils.blackjax_utils import inference_loop
import logging
logger = logging.getLogger()
class CheckTypesFilter(logging.Filter):
    def filter(self, record):
        return "check_types" not in record.getMessage()
logger.addFilter(CheckTypesFilter())
from jax.random import PRNGKey as rng_key
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 2022-07-06 13:08:16.116028: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory

# %% [markdown]
# # Dataset Visualization

# %%
X,Y =  datasets.make_moons(1000, noise=0.20,random_state=6)

# %%
plt.scatter(X[:,0],X[:,1],c=Y,cmap="bwr")
sns.despine()

# %%
X_ood = tfd.MultivariateNormalDiag([2,-2],[0.2,0.2]).sample(seed =rng_key(0),sample_shape=50 )

# %%
plt.scatter(X[:,0],X[:,1],c=Y,cmap="bwr")
plt.scatter(*X_ood.T,c='c')
sns.despine()

# %%
h=0.05
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 2
y_min, y_max = X[:, 1].min() - 2, X[:, 1].max() + 1
xx, yy = jnp.meshgrid(jnp.arange(x_min, x_max, h),
                     jnp.arange(y_min, y_max, h))

# %%
xx.shape
# Out:
# (112, 136)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.5, random_state=45)

# %%
X_train = jnp.array(X_train)
X_test = jnp.array(X_test)
y_train = jnp.array(y_train)
y_test = jnp.array(y_test)

# %% [markdown]
# # Single MLP

# %%
model = cmlp.cmlp([8,16,16,8,1],[nn.relu,nn.relu,nn.relu,nn.relu],[0.03]*4)

# %%
auxs = {
    "X" : X_train,
    "y" : y_train,
    "deterministic": True,
}

# %% [markdown]
# ## Train

# %%
seed=0
params = model.init(jax.random.PRNGKey(seed), X_train, deterministic = True)
params, loss =  fits.fit(model, params,X_train,y_train,True,learning_rate=0.01, epochs=1000,batch_size=64)

# %%
plt.plot(jnp.arange(0,loss.shape[0],1),loss)
sns.despine()

# %%
y_pred_train = model.apply(params, X_train, deterministic=True)
y_pred_test = model.apply(params, X_test, deterministic=True)

# %%
plot_caliberation_classification = partial(plot_caliberation_classification,y_train=y_train,y_test=y_test)

# %%
mlp_pred_train = model.apply(params,X_train,deterministic=True).reshape(y_train.shape)
mlp_pred_test = model.apply(params,X_test,deterministic=True).reshape(y_test.shape)
plot_caliberation_classification(mlp_pred_train,mlp_pred_test,title="MLP")
plt.savefig("figures/MLP_caliberation.pdf")

# %%
os.mkdir("figures")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_58598/1798816764.py in <module>
# ----> 1 os.mkdir("figures")
#
# FileExistsError: [Errno 17] File exists: 'figures'

# %%
p =model.apply(params,jnp.c_[xx.ravel(), yy.ravel()],deterministic=True).reshape(xx.shape)
var = p*(1-p).reshape(xx.shape)

plot_binary_class(X,Y,X_ood,xx,yy,p,titles=("Probability with Single MLP","Variance with Single MLP"))
plt.savefig("figures/mlp_moons.pdf")
#plt.savefig("MLP_moons.pdf")

# %% [markdown]
# # Deep Ensemble

# %%
params_lst= []
loss_lst =[]
for i in range(5):
    params =  model.init(jax.random.PRNGKey(i),X,deterministic=True)
    params,loss = fits.fit(model, params,X_train,y_train,True,learning_rate=0.01, epochs=100)
    params_lst.append(params)
    loss_lst.append(loss)

# %%
p_de_train_ensemble = []
p_de_test_ensemble = []

for i in range(5):
    params = params_lst[i]
    p =model.apply(params,X_train,deterministic=True)
    p_de_train_ensemble.append(p)
    p =model.apply(params,X_test,deterministic=True)
    p_de_test_ensemble.append(p)
ensemble_pred_train = jnp.array(p_de_train_ensemble).mean(axis=0).reshape(y_train.shape)
ensemble_pred_test= jnp.array(p_de_test_ensemble).mean(axis=0).reshape(y_test.shape)

# %%
plot_caliberation_classification(ensemble_pred_train,ensemble_pred_test,title="Deep Ensemble")
plt.savefig("figures/Deep Ensemble caliberation.pdf")

# %%
p_grid_ensemble = []

for i in range(5):
    params = params_lst[i]
    p =  model.apply(params,jnp.c_[xx.ravel(), yy.ravel()],deterministic=True).reshape(xx.shape)
    p_grid_ensemble.append(p)
ensemble_p_mean = jnp.array(p_grid_ensemble).mean(axis=0)
# ensemble_p_sigma =  jnp.array(p_grid_ensemble).std(axis=0)
ensemble_p_sigma = jnp.sqrt(ensemble_p_mean*(1-ensemble_p_mean))

# %%
plot_binary_class(X,Y,X_ood,xx,yy,ensemble_p_mean,titles=("Probability with Deep ensemble","Variance with Deep Ensemble"))
plt.savefig("figures/Deep Ensemble Moons.pdf")

# %% [markdown]
# ### MC Dropout

# %%
y_stacks = []

@jax.jit
def func(params, i):
    z = model.apply(params, jnp.c_[xx.ravel(), yy.ravel()], deterministic=False, 
                    rngs={"dropout": jax.random.PRNGKey(i)}).reshape(xx.shape)
    return z
y_stacks = jax.vmap(fun=func, in_axes=(None, 0))(params, jnp.arange(50))

# %%
mc_pred_mean= jnp.array(y_stacks).mean(axis=0).reshape(xx.shape)
mc_pred_sigma = (jnp.array(y_stacks).std(axis=0)).reshape(yy.shape)

# %%
plot_binary_class(X,Y,X_ood,xx,yy,mc_pred_mean,titles=("Probability with MC Droput","Variance with MC Dropout"))
plt.savefig("figures/MC Dropout Moons.pdf")

# %%
y_stacks_train = []
y_stacks_test = []


def create_apply_func(X_test):
    def func(params, i):
        z = model.apply(params, X_test, deterministic=False, 
                        rngs={"dropout": jax.random.PRNGKey(i)})
        return z
    return func
y_stacks_train = jax.vmap(fun=create_apply_func(X_train), in_axes=(None, 0))(params, jnp.arange(50))
y_stacks_test = jax.vmap(fun=create_apply_func(X_test), in_axes=(None, 0))(params, jnp.arange(50))

# %%
mc_pred_train = y_stacks_train.mean(axis=0)
mc_pred_test = y_stacks_test.mean(axis=0)

# %%
plot_caliberation_classification(mc_pred_train,mc_pred_test,"MC Dropout")
plt.savefig("figures/MC_dropout_caliberation.pdf")

# %% [markdown]
# ### Bootstrap

# %%
num_bootstraps = 10
params_list=[]
loss_list=[]
keys = jax.random.split(jax.random.PRNGKey(0),num_bootstraps)
for i in range(num_bootstraps):
    ids = jax.random.choice(keys[i], jnp.array(range(len(X_train))), (len(X_train),))
    x, y = X_train[ids], y_train[ids]
    params =  model.init(jax.random.PRNGKey(i),X_train,deterministic=True)
    params,loss = fits.fit(model, params, x, y, True, batch_size=len(x), learning_rate=0.01, epochs=100)
    params_list.append(params) 
    loss_list.append(loss)

# %%
bs_train = []
bs_test = []

for i in range(num_bootstraps):
    params = params_list[i]
    b =model.apply(params,X_train,deterministic=True)
    bs_train.append(b)
    b =model.apply(params,X_test,deterministic=True)
    bs_test.append(b)
bootstrap_pred_train = jnp.array(bs_train).mean(axis=0).reshape(y_train.shape)
bootstrap_pred_test= jnp.array(bs_test).mean(axis=0).reshape(y_test.shape)

# %%
plot_caliberation_classification(bootstrap_pred_train,bootstrap_pred_test,title="Bootstrap")
plt.savefig("figures/Bootstrap caliberation.pdf")

# %%
bootstrap = []

for i in range(num_bootstraps):
    params = params_list[i]
    b =  model.apply(params,jnp.c_[xx.ravel(), yy.ravel()],deterministic=True).reshape(xx.shape)
    bootstrap.append(b)
bootstrap_mean = jnp.array(bootstrap).mean(axis=0)
bootstrap_sigma = jnp.sqrt(bootstrap_mean*(1-bootstrap_mean))

# %%
plot_binary_class(X,Y,X_ood,xx,yy,bootstrap_mean,titles=("Probability with Bootstrap","Variance with Bootstrap"))
plt.savefig("figures/Bootstrap Moons.pdf")

# %% [markdown]
# # NUTS

# %%
def bnn_log_joint(params:dict, X, y, model):
    """
    computes the numerator term of the posterior funtion.

    params: dictionary initalized by model 
    X: shape-(n_samples,2) training points 
    y: shape-(n_samples,) labels for training points
    model: bnn model
    """
    
    logits = model.apply(params, X,deterministic=True).ravel()
    # flatten_params gives a list with all the parameters. its dimension will be 1.
    flatten_params, _ = ravel_pytree(params)
    log_prior = tfd.Normal(0.0, 1.0).log_prob(flatten_params).sum()
    log_likelihood = tfd.Bernoulli(logits=logits).log_prob(y).sum()
    log_joint = log_prior + log_likelihood
    return log_joint

params = model.init(jax.random.PRNGKey(0), X_train, deterministic = True)
bnn_log_joint_partial =partial(bnn_log_joint,X=X,y=Y,model=model)
bnn_log_joint_partial(params)
# Out:
# DeviceArray(-1280.5516, dtype=float32)

# %%
from pandas import read_pickle
states,infos = read_pickle("mcmc_moons.pkl")['states'],read_pickle("mcmc_moons.pkl")['infos']

# %%
num_warmup = 100
potential = bnn_log_joint_partial
key = jax.random.PRNGKey(314)
key_samples, key_init, key_warmup, key = jax.random.split(key, 4)
adapt = blackjax.window_adaptation(blackjax.nuts, bnn_log_joint_partial, num_warmup,progress_bar=True)
final_state, kernel, _ = adapt.run(key_warmup, params)
# Out:
# Running window adaptation
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:00<00:00]
#     </div>

# %%
num_samples = 3000
states,infos = inference_loop(key_samples, kernel, final_state, num_samples)

# %%
num_warmup = 1
potential = bnn_log_joint_partial
key = jax.random.PRNGKey(314)
key_samples, key_init, key_warmup, key = jax.random.split(key, 4)
adapt = blackjax.window_adaptation(blackjax.nuts, potential, num_warmup)
final_state, kernel, _ = adapt.run(key_warmup, params)
num_samples = 000
states,infos = inference_loop(key_samples, kernel, final_state, num_samples)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from pandas import to_pickle
to_pickle({"states":states,"infos":infos},"mcmc_moons.pkl")

# %%
seed = jax.random.PRNGKey(0)

def predict_mcmc(x_test):
    def one_step(carry, state):
        params_cur = state.position
        samples = tfd.Bernoulli(probs=model.apply(params_cur,x_test,deterministic=True)).sample(seed=seed)
        return carry, samples
    _, y_stacks = jax.lax.scan(one_step, None, states)
    mean = y_stacks.mean(axis=0)
    std_dev = y_stacks.std(axis=0) 
    return mean,std_dev

mcmc_pred_mean,mcmc_pred_sigma = predict_mcmc(jnp.c_[xx.ravel(), yy.ravel()])
mcmc_pred_mean,mcmc_pred_sigma = mcmc_pred_mean.reshape(xx.shape),mcmc_pred_sigma.reshape(xx.shape)

# %%
mcmc_pred_train, _= predict_mcmc(X_train)
mcmc_pred_test,_ = predict_mcmc(X_test)
plot_caliberation_classification(mcmc_pred_train,mcmc_pred_test,"MCMC")
plt.savefig("figures/MCMC_caliberation.pdf")

# %%
titles_mcmc = ("Mean of Predictions of NUTS","Variance of Predictions of NUTS")
plot_binary_class(X_scatters=X,y_scatters=Y,X_outside=X_ood,XX1_grid=xx,
XX2_grid = yy,grid_preds_mean=mcmc_pred_mean,titles=titles_mcmc)
plt.savefig("figures/BNN using MCMC.pdf")

# %% [markdown]
# # GP

# %%
import GPy
import numpy as np
# h=0.02
# x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
# y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
# xx, yy = jnp.meshgrid(jnp.arange(x_min, x_max, h),
#                      jnp.arange(y_min, y_max, h))

model = GPy.models.GPClassification(np.array(X_train), np.array(y_train.reshape(-1,1)))
print(model)
print(model.log_likelihood())
model.optimize(messages=True)
model.optimize_restarts(num_restarts=5)
print(model)
model.plot_f()
probability_gp,na = model.predict(jnp.c_[xx.ravel(), yy.ravel()])
# Out:
# Name : gp_classification
# Objective : 109.74521506517897
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |  value  |  constraints  |  priors
#   rbf.variance        |    1.0  |      +ve      |
#   rbf.lengthscale     |    1.0  |      +ve      |
# -109.74521506517897
# HBox(children=(VBox(children=(IntProgress(value=0, max=1000), HTML(value=''))), Box(children=(HTML(value=''),)…
# Optimization restart 1/5, f = 57.934702243835716
# Optimization restart 2/5, f = 86.21399026942288
# Optimization restart 3/5, f = 80.48524775622951
# Optimization restart 4/5, f = 61.30723235310836
# Optimization restart 5/5, f = 66.20422569674349
#
# Name : gp_classification
# Objective : 68.27175579859858
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp_classification.  |               value  |  constraints  |  priors
#   rbf.variance        |    13.7540009543266  |      +ve      |
#   rbf.lengthscale     |  0.7116787488864791  |      +ve      |

# %%
probability_gp = probability_gp.reshape(xx.shape)
# sigma_gp = jnp.sqrt(probability_gp*(1-probability_gp)).reshape(xx.shape)

# %%
plot_binary_class(X,Y,X_ood,xx,yy,probability_gp,titles=("Probability with GP","Variance with GP"))
plt.savefig("figures/GP moons.pdf")

# %%
gp_pred_train,na = model.predict(X_train)
gp_pred_test, na = model.predict(X_test)
plot_caliberation_classification(gp_pred_train,gp_pred_test,"GP prediction")
plt.savefig("figures/GP_caliberation.pdf")
# Out:
#  /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:4459: UserWarning:Explicitly requested dtype float requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.

# %% [markdown]
# # SNGP

# %%
# %pip install -qq tf-models-official
# Out:
# Collecting tf-models-official
#   Using cached tf_models_official-2.9.2-py2.py3-none-any.whl (2.1 MB)
# Requirement already satisfied: matplotlib in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (3.5.2)
# Requirement already satisfied: six in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (1.16.0)
# Collecting kaggle>=1.3.9
#   Using cached kaggle-1.5.12.tar.gz (58 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: psutil>=5.4.3 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (5.8.0)
# Requirement already satisfied: numpy>=1.20 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (1.21.5)
# Collecting gin-config
#   Using cached gin_config-0.5.0-py3-none-any.whl (61 kB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting sacrebleu
#   Using cached sacrebleu-2.1.0-py3-none-any.whl (92 kB)
# Requirement already satisfied: Pillow in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (9.0.1)
# Collecting pycocotools
#   Using cached pycocotools-2.0.4.tar.gz (106 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Cython in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (0.29.28)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.17.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 415.2 kB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting pyyaml<6.0,>=5.1
#   Using cached PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Requirement already satisfied: pandas>=0.22.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (1.3.5)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (2.47.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (1.7.3)
# Collecting py-cpuinfo>=3.3.0
#   Using cached py-cpuinfo-8.0.0.tar.gz (99 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow-model-optimization>=0.4.1
#   Using cached tensorflow_model_optimization-0.7.2-py2.py3-none-any.whl (237 kB)
# Collecting tf-slim>=1.1.0
#   Using cached tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# Collecting oauth2client
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: tensorflow-datasets in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tf-models-official) (4.6.0)
# Collecting tensorflow-hub>=0.6.0
#   Using cached tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.3 MB)
# Collecting tensorflow-text~=2.9.0
#   Using cached tensorflow_text-2.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Collecting tensorflow~=2.9.0
#   Downloading tensorflow-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 577.7 kB/s eta 0:00:00m eta 0:00:010:00:19
# Collecting seqeval
#   Using cached seqeval-1.2.2.tar.gz (43 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.6.6)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.20.4)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.7.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (4.1.1)
# Requirement already satisfied: certifi in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from kaggle>=1.3.9->tf-models-official) (2022.5.18.1)
# Requirement already satisfied: python-dateutil in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from kaggle>=1.3.9->tf-models-official) (2.8.2)
# Requirement already satisfied: requests in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from kaggle>=1.3.9->tf-models-official) (2.27.1)
# Requirement already satisfied: tqdm in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from kaggle>=1.3.9->tf-models-official) (4.64.0)
# Requirement already satisfied: python-slugify in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from kaggle>=1.3.9->tf-models-official) (5.0.2)
# Requirement already satisfied: urllib3 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from kaggle>=1.3.9->tf-models-official) (1.26.9)
# Requirement already satisfied: pytz>=2017.3 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from pandas>=0.22.0->tf-models-official) (2021.3)
# Requirement already satisfied: absl-py>=1.0.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (1.0.0)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 1.2 MB/s eta 0:00:001.2 MB/s eta 0:00:01
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: setuptools in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (61.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (1.1.2)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: termcolor>=1.1.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (1.1.0)
# Requirement already satisfied: packaging in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (21.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (2.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (14.0.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (3.3.0)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (1.46.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (4.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (0.25.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (1.13.3)
# Requirement already satisfied: astunparse>=1.6.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow~=2.9.0->tf-models-official) (1.6.3)
# Requirement already satisfied: dm-tree~=0.1.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official) (0.1.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from matplotlib->tf-models-official) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from matplotlib->tf-models-official) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from matplotlib->tf-models-official) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from matplotlib->tf-models-official) (0.11.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from oauth2client->tf-models-official) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from oauth2client->tf-models-official) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from oauth2client->tf-models-official) (4.8)
# Requirement already satisfied: colorama in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from sacrebleu->tf-models-official) (0.4.4)
# Requirement already satisfied: regex in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from sacrebleu->tf-models-official) (2022.3.15)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting tabulate>=0.8.9
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Requirement already satisfied: scikit-learn>=0.21.3 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from seqeval->tf-models-official) (1.0.2)
# Collecting typeguard>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: tensorflow-metadata in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official) (1.8.0)
# Requirement already satisfied: etils[epath] in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official) (0.6.0)
# Requirement already satisfied: importlib-resources in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official) (5.2.0)
# Requirement already satisfied: dill in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official) (0.3.5.1)
# Requirement already satisfied: promise in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official) (2.3)
# Requirement already satisfied: toml in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from astunparse>=1.6.0->tensorflow~=2.9.0->tf-models-official) (0.37.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official) (1.56.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official) (5.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from requests->kaggle>=1.3.9->tf-models-official) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from requests->kaggle>=1.3.9->tf-models-official) (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (2.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official) (3.3.7)
# Requirement already satisfied: zipp in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from etils[epath]->tensorflow-datasets->tf-models-official) (3.7.0)
# Requirement already satisfied: text-unidecode>=1.3 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official) (4.11.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/anand/anaconda3/envs/srip/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official) (3.2.0)
# Building wheels for collected packages: kaggle, py-cpuinfo, pycocotools, seqeval
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73049 sha256=72edcaf5597cbb82ef808924c28116ef193b08acb1d5e601c45f288405c5a5ff
#   Stored in directory: /home/anand/.cache/pip/wheels/62/d6/58/5853130f941e75b2177d281eb7e44b4a98ed46dd155f556dc5
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22258 sha256=005d5de8da880779533458595c68a6c701a4cd10ea5774a396ed9481989c5c2a
#   Stored in directory: /home/anand/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.4-cp37-cp37m-linux_x86_64.whl size=371188 sha256=b42af7a47927f6445cea016e9072fdbfe3688859ad2c469aba1b6c8997e3ad42
#   Stored in directory: /home/anand/.cache/pip/wheels/a3/5f/fa/f011e578cc76e1fc5be8dce30b3eb9fd00f337e744b3bba59b
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=29a87f3b9c24fe3ad88033a661e00b5dc57083a661cf52ef5ecb6efd6b7e9485
#   Stored in directory: /home/anand/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built kaggle py-cpuinfo pycocotools seqeval
# Installing collected packages: sentencepiece, py-cpuinfo, keras, gin-config, flatbuffers, typeguard, tensorflow-model-optimization, tensorflow-estimator, tabulate, pyyaml, protobuf, portalocker, opencv-python-headless, gast, tf-slim, tensorflow-hub, tensorflow-addons, sacrebleu, oauth2client, kaggle, seqeval, pycocotools, tensorboard, tensorflow, tensorflow-text, tf-models-official
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# Successfully installed flatbuffers-1.12 gast-0.4.0 gin-config-0.5.0 kaggle-1.5.12 keras-2.9.0 oauth2client-4.1.3 opencv-python-headless-4.6.0.66 portalocker-2.4.0 protobuf-3.19.4 py-cpuinfo-8.0.0 pycocotools-2.0.4 pyyaml-5.4.1 sacrebleu-2.1.0 sentencepiece-0.1.96 seqeval-1.2.2 tabulate-0.8.10 tensorboard-2.9.1 tensorflow-2.9.1 tensorflow-addons-0.17.1 tensorflow-estimator-2.9.0 tensorflow-hub-0.12.0 tensorflow-model-optimization-0.7.2 tensorflow-text-2.9.0 tf-models-official-2.9.2 tf-slim-1.1.0 typeguard-2.13.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pkg_resources
import importlib
importlib.reload(pkg_resources)
# Out:
# <module 'pkg_resources' from '/home/anand/anaconda3/envs/srip/lib/python3.7/site-packages/pkg_resources/__init__.py'>

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf
try:
    import official.nlp.modeling.layers as nlp_layers
except ModuleNotFoundError:
    # %pip install -qq tf-models-official
    import official.nlp.modeling.layers as nlp_layers

# %%
class DeepResNet(tf.keras.Model):
  """Defines a multi-layer residual network."""
  def __init__(self, num_classes, num_layers=3, num_hidden=128,
               dropout_rate=0.1, **classifier_kwargs):
    super().__init__()
    # Defines class meta data.
    self.num_hidden = num_hidden
    self.num_layers = num_layers
    self.dropout_rate = dropout_rate
    self.classifier_kwargs = classifier_kwargs

    # Defines the hidden layers.
    self.input_layer = tf.keras.layers.Dense(self.num_hidden, trainable=False)
    self.dense_layers = [self.make_dense_layer() for _ in range(num_layers)]

    # Defines the output layer.
    self.classifier = self.make_output_layer(num_classes)

  def call(self, inputs):
    # Projects the 2d input data to high dimension.
    hidden = self.input_layer(inputs)

    # Computes the resnet hidden representations.
    for i in range(self.num_layers):
      resid = self.dense_layers[i](hidden)
      resid = tf.keras.layers.Dropout(self.dropout_rate)(resid)
      hidden += resid

    return self.classifier(hidden)

  def make_dense_layer(self):
    """Uses the Dense layer as the hidden layer."""
    return tf.keras.layers.Dense(self.num_hidden, activation="relu")

  def make_output_layer(self, num_classes):
    """Uses the Dense layer as the output layer."""
    return tf.keras.layers.Dense(
        num_classes, **self.classifier_kwargs)

# %%
class DeepResNetSNGP(DeepResNet):
  def __init__(self, spec_norm_bound=0.9, **kwargs):
    self.spec_norm_bound = spec_norm_bound
    super().__init__(**kwargs)

  def make_dense_layer(self):
    """Applies spectral normalization to the hidden layer."""
    dense_layer = super().make_dense_layer()
    return nlp_layers.SpectralNormalization(
        dense_layer, norm_multiplier=self.spec_norm_bound)

  def make_output_layer(self, num_classes):
    """Uses Gaussian process as the output layer."""
    return nlp_layers.RandomFeatureGaussianProcess(
        num_classes, 
        gp_cov_momentum=-1,
        **self.classifier_kwargs)

  def call(self, inputs, training=False, return_covmat=False):
    # Gets logits and covariance matrix from GP layer.
    logits, covmat = super().call(inputs)

    # Returns only logits during training.
    if not training and return_covmat:
      return logits, covmat

    return logits

# %%
class ResetCovarianceCallback(tf.keras.callbacks.Callback):

  def on_epoch_begin(self, epoch, logs=None):
    """Resets covariance matrix at the beginning of the epoch."""
    if epoch > 0:
      self.model.classifier.reset_covariance_matrix()

# %%
class DeepResNetSNGPWithCovReset(DeepResNetSNGP):
  def fit(self, *args, **kwargs):
    """Adds ResetCovarianceCallback to model callbacks."""
    kwargs["callbacks"] = list(kwargs.get("callbacks", []))
    kwargs["callbacks"].append(ResetCovarianceCallback())

    return super().fit(*args, **kwargs)

# %%
def compute_posterior_mean_probability(logits, covmat, lambda_param=np.pi / 8.):
  # Computes uncertainty-adjusted logits using the built-in method.
  logits_adjusted = nlp_layers.gaussian_process.mean_field_logits(
      logits, covmat, mean_field_factor=lambda_param)

  return tf.nn.softmax(logits_adjusted, axis=-1)[:, 0]

# %%
DEFAULT_X_RANGE = (-3.5, 3.5)
DEFAULT_Y_RANGE = (-2.5, 2.5)
DEFAULT_N_GRID = 100

# %%
def make_training_data(sample_size=500):
  """Create two moon training dataset."""
  train_examples, train_labels = sklearn.datasets.make_moons(
      n_samples=2 * sample_size, noise=0.1)

  # Adjust data position slightly.
  train_examples[train_labels == 0] += [-0.1, 0.2]
  train_examples[train_labels == 1] += [0.1, -0.2]

  return train_examples, train_labels

def make_testing_data(x_range=DEFAULT_X_RANGE, y_range=DEFAULT_Y_RANGE, n_grid=DEFAULT_N_GRID):
  """Create a mesh grid in 2D space."""
  # testing data (mesh grid over data space)
  x = np.linspace(x_range[0], x_range[1], n_grid)
  y = np.linspace(y_range[0], y_range[1], n_grid)
  xv, yv = np.meshgrid(x, y)
  return np.stack([xv.flatten(), yv.flatten()], axis=-1),xv,yv

X_train,y_train = make_training_data(
    sample_size=500)

X_test,xx,yy = make_testing_data()

# %%
def train_and_test_sngp(X_train, X_test):
  sngp_model = DeepResNetSNGPWithCovReset(**resnet_config)

  sngp_model.compile(**train_config)
  sngp_model.fit(X_train, np.array(y_train), verbose=0, **fit_config)

  sngp_logits, sngp_covmat = sngp_model(X_test, return_covmat=True)
  sngp_probs = compute_posterior_mean_probability(sngp_logits, sngp_covmat)

  return sngp_probs

# %%
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metrics = tf.keras.metrics.SparseCategoricalAccuracy(),
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
resnet_config = dict(num_classes=2, num_layers=6, num_hidden=128)
train_config = dict(loss=loss, metrics=metrics, optimizer=optimizer)
fit_config = dict(batch_size=128, epochs=1000)
# Out:
# 2022-07-02 11:17:18.439919: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-02 11:17:18.439951: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)

# %%
X_train.shape
# Out:
# (1000, 2)

# %%
import numpy as np
sngp_probs = train_and_test_sngp(np.array(X_train), X_test)

# %%
sngp_std = np.sqrt(sngp_probs*(1-sngp_probs))

# %%
sngp_probs = jnp.array(sngp_probs).reshape(xx.shape)

# %%
sngp_std = jnp.array(sngp_std).reshape(xx.shape)

# %%
plot_binary_class(X,Y,xx,yy,sngp_probs,sngp_std,titles=("Probability with SNGP","Variance with SNGP"))

# %%
plot_binary_class(X,Y,xx,yy,sngp_probs,sngp_std,titles=("Probability with SNGP","Variance with SNGP"))

# %%
sngp_pred_train = train_and_test_sngp(np.array(X_train), X_train)

# %%
# sngp_pred_test = train_and_test_sngp(np.array(X_train), X_train)

# %%
def plot_caliberation_classification(pred_train,pred_test,title):
    fig,ax1 = plt.subplots(1,1)
    prob_true_train,prob_pred_train = calibration_curve(y_train,pred_train,n_bins=5)
    # prob_true_test,prob_pred_test = calibration_curve(y_train,pred_test)

    disp_train = CalibrationDisplay(prob_true_train,prob_pred_train,pred_train,estimator_name="Train")
    # disp_test = CalibrationDisplay(prob_true_test,prob_pred_test,pred_test,estimator_name="Test",)

    disp_train.plot(ax=ax1)
    # disp_test.plot(ax=ax1)
    sns.despine(ax=ax1)
    ax1.legend(loc=0)
    ax1.set_title(title)

# %%
plot_caliberation_classification(sngp_pred_train,sngp_pred_train,"SNGP")
